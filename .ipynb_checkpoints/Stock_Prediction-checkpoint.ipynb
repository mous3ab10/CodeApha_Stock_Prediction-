# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import datetime
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
# Out:
# C:\Users\legion\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Data Understanding

# %%
stock = pd.read_csv("MSFT.csv")
stock.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.059946  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062087   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063158   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061552    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060482    47894400
# 5  1986-03-20  0.098090  0.098090  0.094618  0.095486   0.058876    58435200
# 6  1986-03-21  0.095486  0.097222  0.091146  0.092882   0.057270    59990400
# 7  1986-03-24  0.092882  0.092882  0.089410  0.090278   0.055665    65289600
# 8  1986-03-25  0.090278  0.092014  0.089410  0.092014   0.056735    32083200
# 9  1986-03-26  0.092014  0.095486  0.091146  0.094618   0.058341    22752000

# %%
stock.sample(5)
# Out:
#             Date       Close
# 8954  2021-09-21  294.799988
# 4449  2003-10-28   27.200001
# 2431  1995-10-23    6.023438
# 6946  2013-09-30   33.279999
# 5551  2008-03-17   28.299999

# %%
stock.shape
# Out:
# (9690, 2)

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9690 entries, 0 to 9689
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9690 non-null   object
#  1   Close   9690 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 151.5+ KB

# %%
stock.describe()
# Out:
#              Close
# count  9690.000000
# mean     59.075507
# std      91.345716
# min       0.090278
# 25%       5.712891
# 50%      27.360001
# 75%      46.757499
# max     467.559998

# %%
stock["Close"].skew()
# Out:
# 2.357377169874328

# %%
bins = np.arange(0 , stock["Close"].max() + 10 , 10)
plt.hist(data = stock , x = "Close" , bins = bins , rwidth = 0.8)
plt.xticks(bins , rotation = 90);

# %%
stock["Date"].max()
# Out:
# '2024-08-23'

# %%
stock.isnull().sum()
# Out:
# Date     0
# Close    0
# dtype: int64

# %% [markdown]
# # Data Cleaning and Preprocessing

# %% [markdown]
# ### Correct Format

# %%
stock['Date'] = pd.to_datetime(stock['Date'])
stock.info()
stock.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9690 entries, 0 to 9689
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9690 non-null   datetime64[ns]
#  1   Close   9690 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 151.5 KB
#         Date     Close
# 0 1986-03-13  0.097222
# 1 1986-03-14  0.100694
# 2 1986-03-17  0.102431
# 3 1986-03-18  0.099826
# 4 1986-03-19  0.098090
# 5 1986-03-20  0.095486
# 6 1986-03-21  0.092882
# 7 1986-03-24  0.090278
# 8 1986-03-25  0.092014
# 9 1986-03-26  0.094618

# %%
time_interval = (stock["Date"].max() - stock["Date"].min()) / 365
print(time_interval)
# Out:
# 38 days 11:22:31.232876712

# %% [markdown]
# ### Hundle Outliers

# %%
plt.figure(figsize = [20 , 20])

for i in range(9):
    plt.subplot(3 , 3 , i + 1)
    bins = np.arange(0 , stock["Close"].max() + 5 + i , 5 + i)
    plt.hist(data = stock , x = "Close" , bins = bins)
    #plt.xticks(bins , rotation = 90)
    plt.xlabel("With Bin Width : " + str(5 + i))

# %%
bins = np.arange(0 , stock["Close"].max() + 9 , 9)
plt.hist(data = stock , x = "Close" , bins = bins)
plt.xticks(bins , rotation = 90)
plt.xlabel("With Bin Width : " + str(9))
plt.xlim((0 , 351));

# %%
sb.boxplot(x = stock["Close"]);

# %%
out_index = stock[stock["Close"] > 351].index
print(len(out_index))
stock = stock.drop(out_index , axis = 0)
stock["Close"].describe()
# Out:
# 204
# count    9486.000000
# mean       51.563295
# std        76.341736
# min         0.090278
# 25%         5.476563
# 50%        27.187500
# 75%        44.966562
# max       350.980011
# Name: Close, dtype: float64

# %%
plt.figure(figsize = [10 , 5])

plt.subplot(1 , 2 , 1)
bins = np.arange(0 , stock["Close"].max() + 9 , 9)
plt.hist(data = stock , x = "Close" , bins = bins)
plt.xticks(bins , rotation = 90)
plt.xlabel("With Bin Width : " + str(9))

plt.subplot(1 , 2 , 2)
sb.boxplot(x = stock["Close"]);

# %%
stock = stock.set_index("Date")

# %% [markdown]
# # Data Exploration (EDA)

# %%
stock.head(10)
# Out:
#                Close
# Date
# 1986-03-13  0.097222
# 1986-03-14  0.100694
# 1986-03-17  0.102431
# 1986-03-18  0.099826
# 1986-03-19  0.098090
# 1986-03-20  0.095486
# 1986-03-21  0.092882
# 1986-03-24  0.090278
# 1986-03-25  0.092014
# 1986-03-26  0.094618

# %%
plt.plot(stock.index , stock["Close"]);

# %%
plt.figure(figsize = [20 , 20])

first = 1981
for i in range(9):
    plt.subplot(3 , 3 , i + 1)
    first += 5
    if first == 2026:
        first = 2023
        stock_year = stock[stock.index.year == first]
    else:
        stock_year = stock[stock.index.year == first]
    plt.plot(stock_year.index , stock_year["Close"]) 
    plt.xlabel("Year : " + str(first))
    plt.xticks(rotation = 90);

# %% [markdown]
# # LSTM

# %%
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

# %%
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(stock, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %% [markdown]
# ### Spliting Data

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %% [markdown]
# ### Model Building

# %%
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 84106.7422 - mean_absolute_error: 288.2254 - val_loss: 92384.8203 - val_mean_absolute_error: 303.8616
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 84970.3750 - mean_absolute_error: 289.8069 - val_loss: 92153.3828 - val_mean_absolute_error: 303.4805
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 83636.4062 - mean_absolute_error: 287.5994 - val_loss: 91917.6484 - val_mean_absolute_error: 303.0919
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 83950.1016 - mean_absolute_error: 287.9607 - val_loss: 91638.6172 - val_mean_absolute_error: 302.6312
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 83692.7422 - mean_absolute_error: 287.4236 - val_loss: 91296.4922 - val_mean_absolute_error: 302.0654
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 83880.4766 - mean_absolute_error: 287.9188 - val_loss: 90816.7188 - val_mean_absolute_error: 301.2702
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 84650.1406 - mean_absolute_error: 289.3705 - val_loss: 90004.5312 - val_mean_absolute_error: 299.9192
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 81856.3828 - mean_absolute_error: 284.2870 - val_loss: 88952.2734 - val_mean_absolute_error: 298.1598
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 80893.1172 - mean_absolute_error: 282.6805 - val_loss: 87569.8984 - val_mean_absolute_error: 295.8323
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 79281.5781 - mean_absolute_error: 279.8068 - val_loss: 85613.9297 - val_mean_absolute_error: 292.5079
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 78933.3281 - mean_absolute_error: 279.1355 - val_loss: 83332.9922 - val_mean_absolute_error: 288.5827
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 75445.4688 - mean_absolute_error: 272.9374 - val_loss: 80715.9297 - val_mean_absolute_error: 284.0121
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 71908.9297 - mean_absolute_error: 266.3153 - val_loss: 77792.2422 - val_mean_absolute_error: 278.8176
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 69552.0469 - mean_absolute_error: 261.7308 - val_loss: 73978.8516 - val_mean_absolute_error: 271.8929
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 65299.9883 - mean_absolute_error: 253.6028 - val_loss: 69556.9219 - val_mean_absolute_error: 263.6360
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 61965.2656 - mean_absolute_error: 246.9541 - val_loss: 65000.5898 - val_mean_absolute_error: 254.8479
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 57368.4531 - mean_absolute_error: 237.4299 - val_loss: 59941.4297 - val_mean_absolute_error: 244.7211
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 52544.9844 - mean_absolute_error: 227.0828 - val_loss: 54515.6641 - val_mean_absolute_error: 233.3720
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 46735.1875 - mean_absolute_error: 213.8772 - val_loss: 48672.2500 - val_mean_absolute_error: 220.4978
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 42282.1562 - mean_absolute_error: 203.1221 - val_loss: 42891.9219 - val_mean_absolute_error: 206.9757
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 36923.7188 - mean_absolute_error: 189.3924 - val_loss: 37065.9336 - val_mean_absolute_error: 192.3874
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30776.3730 - mean_absolute_error: 172.6604 - val_loss: 31040.5176 - val_mean_absolute_error: 176.0321
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25166.5312 - mean_absolute_error: 155.3491 - val_loss: 24500.8477 - val_mean_absolute_error: 156.3576
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19896.4414 - mean_absolute_error: 137.3975 - val_loss: 18958.6328 - val_mean_absolute_error: 137.4979
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14871.2363 - mean_absolute_error: 117.8075 - val_loss: 14313.7930 - val_mean_absolute_error: 119.4187
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10726.6240 - mean_absolute_error: 98.4410 - val_loss: 10363.4004 - val_mean_absolute_error: 101.5403
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8054.8315 - mean_absolute_error: 83.5969 - val_loss: 7157.1294 - val_mean_absolute_error: 84.2862
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4857.4814 - mean_absolute_error: 62.0473 - val_loss: 4758.7192 - val_mean_absolute_error: 68.5973
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3656.3044 - mean_absolute_error: 51.6185 - val_loss: 2878.2700 - val_mean_absolute_error: 53.1536
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2142.1580 - mean_absolute_error: 36.9110 - val_loss: 1728.8154 - val_mean_absolute_error: 40.9371
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1607.8845 - mean_absolute_error: 33.0033 - val_loss: 1027.4259 - val_mean_absolute_error: 31.2163
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1250.3143 - mean_absolute_error: 29.8466 - val_loss: 626.4670 - val_mean_absolute_error: 23.9479
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1014.7943 - mean_absolute_error: 27.0051 - val_loss: 423.1264 - val_mean_absolute_error: 19.2395
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 971.4359 - mean_absolute_error: 25.7893 - val_loss: 315.9106 - val_mean_absolute_error: 16.2156
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 970.2441 - mean_absolute_error: 26.1789 - val_loss: 269.5085 - val_mean_absolute_error: 14.7960
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1018.5721 - mean_absolute_error: 26.9604 - val_loss: 257.2515 - val_mean_absolute_error: 14.4072
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1011.0609 - mean_absolute_error: 26.9835 - val_loss: 251.5954 - val_mean_absolute_error: 14.2239
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 966.0269 - mean_absolute_error: 25.9513 - val_loss: 251.7869 - val_mean_absolute_error: 14.2302
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1021.2432 - mean_absolute_error: 27.0021 - val_loss: 257.0419 - val_mean_absolute_error: 14.4005
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1030.5854 - mean_absolute_error: 26.7995 - val_loss: 263.5543 - val_mean_absolute_error: 14.6085
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 992.0891 - mean_absolute_error: 26.5686 - val_loss: 286.9156 - val_mean_absolute_error: 15.3296
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1016.8207 - mean_absolute_error: 26.6258 - val_loss: 294.3980 - val_mean_absolute_error: 15.5529
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 981.1876 - mean_absolute_error: 26.4939 - val_loss: 290.4679 - val_mean_absolute_error: 15.4360
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 983.5903 - mean_absolute_error: 26.5730 - val_loss: 289.0361 - val_mean_absolute_error: 15.3932
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1011.5648 - mean_absolute_error: 26.6315 - val_loss: 288.1532 - val_mean_absolute_error: 15.3668
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 976.6143 - mean_absolute_error: 26.4933 - val_loss: 294.1235 - val_mean_absolute_error: 15.5447
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 968.8451 - mean_absolute_error: 26.3886 - val_loss: 290.0838 - val_mean_absolute_error: 15.4246
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1019.4591 - mean_absolute_error: 27.2016 - val_loss: 278.5888 - val_mean_absolute_error: 15.0769
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1019.8775 - mean_absolute_error: 27.0861 - val_loss: 268.0502 - val_mean_absolute_error: 14.7503
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 898.2678 - mean_absolute_error: 24.6001 - val_loss: 260.3658 - val_mean_absolute_error: 14.5072
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1061.9163 - mean_absolute_error: 28.0770 - val_loss: 286.1597 - val_mean_absolute_error: 15.3206
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 986.0270 - mean_absolute_error: 26.7762 - val_loss: 286.3673 - val_mean_absolute_error: 15.3294
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 936.5856 - mean_absolute_error: 25.6582 - val_loss: 266.9785 - val_mean_absolute_error: 14.7385
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 929.7672 - mean_absolute_error: 25.6335 - val_loss: 337.1066 - val_mean_absolute_error: 16.9733
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 870.3763 - mean_absolute_error: 24.9294 - val_loss: 196.4973 - val_mean_absolute_error: 12.3181
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 985.7730 - mean_absolute_error: 26.6109 - val_loss: 326.3432 - val_mean_absolute_error: 16.6158
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 943.9923 - mean_absolute_error: 26.3800 - val_loss: 192.6406 - val_mean_absolute_error: 12.1990
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 930.5782 - mean_absolute_error: 25.6520 - val_loss: 282.6240 - val_mean_absolute_error: 15.2672
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 926.5287 - mean_absolute_error: 25.8768 - val_loss: 302.9321 - val_mean_absolute_error: 15.9448
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 975.0969 - mean_absolute_error: 26.6844 - val_loss: 374.0273 - val_mean_absolute_error: 18.0598
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 855.6807 - mean_absolute_error: 24.5947 - val_loss: 264.1462 - val_mean_absolute_error: 14.7433
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 829.5965 - mean_absolute_error: 24.0228 - val_loss: 205.7228 - val_mean_absolute_error: 12.7752
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 830.0407 - mean_absolute_error: 23.9532 - val_loss: 339.5018 - val_mean_absolute_error: 17.1189
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 858.2565 - mean_absolute_error: 24.9735 - val_loss: 200.3443 - val_mean_absolute_error: 12.6098
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 765.0498 - mean_absolute_error: 23.3725 - val_loss: 287.0813 - val_mean_absolute_error: 15.5600
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 721.5471 - mean_absolute_error: 22.4847 - val_loss: 203.5429 - val_mean_absolute_error: 12.7604
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 756.8346 - mean_absolute_error: 23.3134 - val_loss: 217.3202 - val_mean_absolute_error: 13.2843
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 640.3695 - mean_absolute_error: 21.2878 - val_loss: 253.6257 - val_mean_absolute_error: 14.6183
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 572.6735 - mean_absolute_error: 19.8336 - val_loss: 205.6052 - val_mean_absolute_error: 12.9156
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 539.9268 - mean_absolute_error: 19.0154 - val_loss: 126.1118 - val_mean_absolute_error: 9.6538
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 509.0356 - mean_absolute_error: 18.8252 - val_loss: 104.0836 - val_mean_absolute_error: 8.5655
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 452.8538 - mean_absolute_error: 17.8017 - val_loss: 104.9821 - val_mean_absolute_error: 8.6716
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 418.2654 - mean_absolute_error: 17.1605 - val_loss: 123.0923 - val_mean_absolute_error: 9.6002
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 385.4286 - mean_absolute_error: 16.0677 - val_loss: 84.6055 - val_mean_absolute_error: 7.6176
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 353.6089 - mean_absolute_error: 15.3060 - val_loss: 101.3854 - val_mean_absolute_error: 8.5732
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 324.3093 - mean_absolute_error: 14.9329 - val_loss: 111.4547 - val_mean_absolute_error: 9.0949
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 297.3539 - mean_absolute_error: 14.1413 - val_loss: 46.6771 - val_mean_absolute_error: 5.4718
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 284.5388 - mean_absolute_error: 14.1338 - val_loss: 155.6395 - val_mean_absolute_error: 11.1402
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 248.8930 - mean_absolute_error: 12.9409 - val_loss: 86.4979 - val_mean_absolute_error: 7.8326
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 190.8241 - mean_absolute_error: 11.0616 - val_loss: 47.1073 - val_mean_absolute_error: 5.5712
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 176.8771 - mean_absolute_error: 10.7934 - val_loss: 34.6460 - val_mean_absolute_error: 5.0635
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 159.7283 - mean_absolute_error: 10.1573 - val_loss: 33.2659 - val_mean_absolute_error: 4.8672
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 163.2749 - mean_absolute_error: 10.6384 - val_loss: 31.1660 - val_mean_absolute_error: 4.8410
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 122.5752 - mean_absolute_error: 8.9798 - val_loss: 30.9637 - val_mean_absolute_error: 4.8392
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 109.6554 - mean_absolute_error: 8.5903 - val_loss: 41.6296 - val_mean_absolute_error: 5.2455
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 102.8309 - mean_absolute_error: 8.4912 - val_loss: 41.9084 - val_mean_absolute_error: 5.1936
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 93.2269 - mean_absolute_error: 8.1662 - val_loss: 48.0261 - val_mean_absolute_error: 5.4930
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 81.0092 - mean_absolute_error: 7.4870 - val_loss: 38.9315 - val_mean_absolute_error: 5.0384
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 60.9569 - mean_absolute_error: 6.1683 - val_loss: 36.2569 - val_mean_absolute_error: 4.9364
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 57.8802 - mean_absolute_error: 5.6831 - val_loss: 30.6676 - val_mean_absolute_error: 4.8225
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 45.0047 - mean_absolute_error: 4.8439 - val_loss: 30.5859 - val_mean_absolute_error: 4.7948
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 40.3936 - mean_absolute_error: 4.7678 - val_loss: 47.1689 - val_mean_absolute_error: 5.4111
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 42.7267 - mean_absolute_error: 5.3389 - val_loss: 76.3385 - val_mean_absolute_error: 7.0591
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 40.7621 - mean_absolute_error: 5.3089 - val_loss: 34.6182 - val_mean_absolute_error: 4.8542
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.8108 - mean_absolute_error: 4.2606 - val_loss: 43.2420 - val_mean_absolute_error: 5.2563
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 33.4639 - mean_absolute_error: 4.6883 - val_loss: 49.8312 - val_mean_absolute_error: 5.6335
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 29.3315 - mean_absolute_error: 4.4847 - val_loss: 58.0148 - val_mean_absolute_error: 6.0119
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.1743 - mean_absolute_error: 4.1216 - val_loss: 47.3196 - val_mean_absolute_error: 5.5200
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 28.5946 - mean_absolute_error: 4.2250 - val_loss: 37.2161 - val_mean_absolute_error: 4.9154
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.7369 - mean_absolute_error: 3.9242 - val_loss: 46.7528 - val_mean_absolute_error: 5.8328

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
